# %% [markdown]
# ## El comando SSH
# SSH - Secure Shell
# Puedes pensarlo como una manera de acceder a otra computadora
#
# Ejemplo:
# ssh -i directory/key.pem user@ipaddress

# %% [markdown]
# ## Corriendo linux en un contenedor
#
# https://github.com/nickjj/docker-django-example
#
# git clone https://github.com/nickjj/docker-django-example hellodjango
#
# cd hellodjango
#
# cp .env.example .env
#
# docker compose up --build
#
# docker exec -it hellodjango-web-1 bash
#
# cat /etc/issue

# %% [markdown]
# ## Principales carpetas en Linux

# %%
from IPython import display
display.Image("https://i.sstatic.net/3u7dC.jpg")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from IPython import display
# ----> 2 display.Image("https://i.sstatic.net/3u7dC.jpg")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\display.py:1025, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1023 self.unconfined = unconfined
#    1024 self.alt = alt
# -> 1025 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1026         metadata=metadata)
#    1028 if self.width is None and self.metadata.get('width', {}):
#    1029     self.width = metadata['width']
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\display.py:343, in DisplayObject.__init__(self, data, url, filename, metadata)
#     340 elif self.metadata is None:
#     341     self.metadata = {}
# --> 343 self.reload()
#     344 self._check_data()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\display.py:1060, in Image.reload(self)
#    1058 """Reload the raw data from file or URL."""
#    1059 if self.embed:
# -> 1060     super(Image,self).reload()
#    1061     if self.retina:
#    1062         self._retina_shape()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\display.py:374, in DisplayObject.reload(self)
#     371 elif self.url is not None:
#     372     # Deferred import
#     373     from urllib.request import urlopen
# --> 374     response = urlopen(self.url)
#     375     data = response.read()
#     376     # extract encoding from header, if there is one:
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:533, in OpenerDirector.error(self, proto, *args)
#     531 if http_err:
#     532     args = (dict, 'default', 'http_error_default') + orig_args
# --> 533     return self._call_chain(*args)
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Visitar: https://i.sstatic.net/3u7dC.jpg

# %% [markdown]
# ## Comandos esenciales para moverse en la terminal de Linux

# %% [markdown]
# pwd - print working directory - imprime la ruta del directorio en el que estamos
#
# ls - list - lista los archivos y carpetas en el directorio en el que estamos
#
# cd - change directory - cambiar de directorio/carpeta (usar .. para carpeta anterior)
#
# clear - limpiar la terminal
#
# mkdir - make directory - crea una carpeta
#
# touch - crear archivos dentro de la carpeta actual
#
# cp - copy - copiar
#
# mv - move - mover o renombrar
#
# rm - remove - eliminar (usar -r para eliminar carpetas)

# %% [markdown]
# ## Introducción a Django
#
# ¿Qué es Django?
# - "Web framework for perfectionist with deadlines"
# - Motiva el desarrollo rápido de sitios web de forma limpia y estructurada
# - Es usado por Instagram, Youtube, Spotify y muchas otras Empresas
#
# ¿Por qué lo necesitamos?
# - Con HTML, CSS, JS podemos crear sitios web estáticos (Frontend)
# - Pero además queremos crear comportamientos a la medida haciendo uso de bases de datos (Backend)
# - Django nos ayuda a cubrir todo esto

# %% [markdown]
# ## Migraciones
# (Los cambios a la base de datos, base de datos es donde almacenamos la información)
#
# En este proyecto:
# ./run manage migrate
#
# En Django standard:
# python manage.py migrate
#
# Vistar el sitio web: http://localhost:8000/

# %% [markdown]
# ## Proyecto y Aplicación

# %% [markdown]
# pip freeze
#
# amqp==5.3.1
# asgiref==3.11.0
# billiard==4.2.1
# celery==5.6.2
# click==8.1.8
# click-didyoumean==0.3.1
# click-plugins==1.1.1
# click-repl==0.3.0
# Django==6.0.2
# django-debug-toolbar==6.2.0
# gunicorn==25.1.0
# kombu==5.6.1
# packaging==24.2
# prompt_toolkit==3.0.50
# psycopg==3.3.3
# python-dateutil==2.9.0.post0
# redis==7.2.1
# ruff==0.15.4
# setuptools==82.0.0
# six==1.17.0
# sqlparse==0.5.3
# tzdata==2025.2
# tzlocal==5.3.1
# vine==5.1.0
# wcwidth==0.2.13
# whitenoise==6.12.0

# %% [markdown]
# ## Estructura de un Proyecto en Django

# %% [markdown]
# ### Archivos de Proyecto
# - manage.py: es un archivo que contiene muchas funciones que te permiten interactuar con Django
# - config/init.py: un archivo vacío que le informa a Pyhton que este directorio/carpeta debería ser considerado como un paquete de Python
# - config/settings.py: Configuración o ajustes para el proyecto en django
# - config/urls.py: las declaraciones de los urls para el proyecto django. Es como una tabla de contenidos con los endpoints del sitio web
# - config/asgi.py: un punto de entrada para servidores web compatibles con ASGI para desplegar el proyecto
# - config/wsgi.py: un punto de entrada para servidores web compatibles con WSGI para desplegar el proyecto

# %% [markdown]
# ### Archivos de Aplicación
# - admin.py: registrar tus modelos relacionados con el django admin
# - apps.py: contiene el código de la configuración de la app
# - models.py: define tus modelos aquí. Son las tablas en la base de datos para almacenar la información y definir sus relaciones
# - tests.py: escribir tests para la app
# - views.py: definir la información que será mandada a los templates del frontend

# %% [markdown]
# ## Haz tus primeros cambios visibles en tu proyecto
